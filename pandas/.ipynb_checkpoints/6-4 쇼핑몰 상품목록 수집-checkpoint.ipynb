# %% [markdown]
# # 6-4. 쇼핑몰 상품목록 수집
# > 페이지 번호를 이동하면서 수집하기
#
# http://itproject.ezenac.co.kr/springmyshop/product/best 에서 특정 상품을 검색 후 모든 페이지에 대한 상품 목록을 출력하여 엑셀로 저장하시오.
# 단, 상품 정보의 모든 페이지를 반복적으로 수집해야 합니다.
# > ex) 팬츠에 대한 검색결과가 7페이지인 경우 7페이지에 대한 모든 데이터 수집
#
# # #01. 필요한 모듈 참조

# %%
import requests      # -> 웹 페이지 요청 모듈
import urllib        # -> URLEncoding을 위한 모듈
from bs4 import BeautifulSoup
from pandas import DataFrame

# %% [markdown]
# # #02. 수집 준비
# ## 1) 접속을 수행하기 위한 session 객체 생성

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36"
session= requests.Session()
session.headers.update({'User-agent':user_agent, 'referer':None})

# %% [markdown]
# ## 2) 접근할 페이지 주소
# ### 필요한 변수들 정의

# %%
keyword = "팬츠"

# %% [markdown]
# ### 기본 URL
# 브라우저에 표시되는 검색결과 URL에서 `?` 전까지만 지정

# %%
base_url = "http://itproject.ezenac.co.kr/springmyshop/product/best"

# %% [markdown]
# ### 파라미터 구조
# 2페이지부터 3~4페이지 정도 직접 이동하여 주소를 확인한 후 패턴을 찾는다.
# > page=1&keyword=검색어

# %%
base_param = {'page' : 1, 'keyword' : keyword}
base_param
# Out:
# {'page': 1, 'keyword': '팬츠'}

# %% [markdown]
# # #03. 반복 수행으로 데이터 수집하기
# 개별 상품 정보들을 딕셔너리 형태로 수집한 다음 미리 준비한 빈 리스트에 추가한다.

# %%
# 수집 결과를 누적할 빈 리스트
data_list = []

base_param['page']=1

#직접 접속하기 전까지는 검색결과가 몇 페이지인지 모르는 상태
while True:
    #--------------------------------------------------
    # 1) 접속할 주소 준비하기
    #--------------------------------------------------
    # URL Encoding
    query = urllib.parse.urlencode(base_param)
    
    # 접속할 주소 확정
    content_url = base_url+'?'+query
    print(content_url)
    #break
    
    #--------------------------------------------------
    # 2) 페이지에 접속하기
    #--------------------------------------------------
    r = session.get(content_url)
    
    # 접속 실패 시 다음 항목으로 반복문 제어 이동
    if r.status_code != 200:
        print("%d Error가 발생했습니다." % r.status_code)
        continue
    
    r.encoding='utf-8' # 컨텐츠의 인코딩 형식 설정
    
    # 웹 페이지의 소스코드 HTML 분석 객체로 생성
    soup = BeautifulSoup(r.text, 'html.parser')
    #break
    
    #--------------------------------------------------
    # 3) 상품정보 추출
    #--------------------------------------------------
    product_item = soup.select('.product-item')
    
    # 상품 수만큼 반복
    for item in product_item:
        #상품명
        name=item.select('h3')
        name=name[0].text.strip()
        print(name)
        
        #상품가격
        price = item.select('.price')
        price_str = price[0].text.strip()
        
        #정가와 할인가가 나누어져 있는 경우
        if price_str.count('원') == 2:
            origin_price = price[0].select('.cancel-price')[0].text.strip()
            sale_price = price[0].select('.sale-price')[0].text.strip()
        # 정가만 있는 경우
        else :
            origin_price = price_str
            sale_price = None
            
        # 가격 문자열에서 불필요한 글자와 공백을 제거 후 정수로 변환
        origin_price = int(origin_price.replace('원', '').replace(',','').strip())
        
        if sale_price:
            sale_price = int(sale_price.replace('원', '').replace(',','').strip())
            
        print('정가 : %s, 할인가 : %s' % (origin_price, sale_price))
        
        # 상품설명
        desc = item.select('.desc')[0].text.strip()
        
        product_dic = { '상품명' : name,
                       '정가' : origin_price,
                       '할인가' : sale_price,
                       '설명' : desc  }
        #print(product_dic)
        
        # 상품 개별 정보를 리스트에 병합
        data_list.append(product_dic)
        
    #--------------------------------------------------
    # 4) 전체 페이지 수를 가져와서 반복 실행 여부 판단하기
    #--------------------------------------------------
    text_muted = soup.select('.text-muted')
    # -> (1/7Pages.)
    page_info = text_muted[0].text.strip()
    p = page_info.find('/')
    max_page = int(page_info[p+1:-7])
    
    # 페이지 번호 1 증가
    base_param['page'] += 1
    
    # 원하는 조건이 성립한 경우 처리 중단
    if base_param['page'] > max_page:
        break
# Out:
# http://itproject.ezenac.co.kr/springmyshop/product/best?page=1&keyword=%ED%8C%AC%EC%B8%A0
# 블린체휘트니스팬츠
# 정가 : 25900, 할인가 : None
# 플러튼휘트니스팬츠
# 정가 : 25900, 할인가 : None
# 메이건7부트레이닝팬츠
# 정가 : 15900, 할인가 : None
# 루더스휘트니스치마팬츠
# 정가 : 19900, 할인가 : None
# 론사선트레이닝팬츠
# 정가 : 21900, 할인가 : 13140
# 페버휘트니스팬츠
# 정가 : 19900, 할인가 : None
# 치크네온트레이닝팬츠
# 정가 : 17900, 할인가 : None
# 바루스휘트니스팬츠
# 정가 : 19900, 할인가 : None
# 베이브 휘트니스팬츠
# 정가 : 29900, 할인가 : None
# 네듀휘트니스팬츠
# 정가 : 19900, 할인가 : None
# 데로피트니스팬츠
# 정가 : 19900, 할인가 : None
# 퓨어코 휘트니스팬츠
# 정가 : 29900, 할인가 : None
# 발링휘트니스팬츠
# 정가 : 19900, 할인가 : None
# 미네추트레이닝팬츠
# 정가 : 23900, 할인가 : 16730
# 엘샤드 휘트니스팬츠
# 정가 : 19800, 할인가 : None
# 퍼드 트레이닝팬츠
# 정가 : 18800, 할인가 : None
# 이엔트레이닝팬츠
# 정가 : 16900, 할인가 : None
# 카엘린 트레이닝팬츠
# 정가 : 14900, 할인가 : None
# 점핑트레이닝팬츠
# 정가 : 14900, 할인가 : None
# 말리아휘트니스팬츠
# 정가 : 16900, 할인가 : None
# 로미슈 휘트니스팬츠
# 정가 : 18900, 할인가 : None
# 유키라 휘트니스팬츠
# 정가 : 17900, 할인가 : None
# 시글리 휘트니스팬츠
# 정가 : 19900, 할인가 : None
# 리틀팜 휘트니스팬츠
# 정가 : 17900, 할인가 : None
# 힙V피트니스팬츠
# 정가 : 19900, 할인가 : None
# 벤슬러 휘트니스팬츠
# 정가 : 16000, 할인가 : None
# 알리트 휘트니스팬츠
# 정가 : 15800, 할인가 : None
# 올트 트레이닝팬츠
# 정가 : 15900, 할인가 : None
# 렘브3부숏팬츠
# 정가 : 18900, 할인가 : None
# 지엔로 피트니스팬츠
# 정가 : 21900, 할인가 : None
# 썸V힙피트니스7부팬츠
# 정가 : 18900, 할인가 : None
# 핑파휘트니스 팬츠
# 정가 : 19900, 할인가 : None
# 리키아트레이닝팬츠
# 정가 : 24800, 할인가 : None
# 잭스틴 휘트니스7부팬츠
# 정가 : 13900, 할인가 : None
# F-벨티스보드숏팬츠
# 정가 : 24800, 할인가 : None
# 더니크 휘트니스팬츠
# 정가 : 23900, 할인가 : None
# http://itproject.ezenac.co.kr/springmyshop/product/best?page=2&keyword=%ED%8C%AC%EC%B8%A0
# 링튼트레이닝팬츠
# 정가 : 15800, 할인가 : None
# 비에7부 트레이닝팬츠
# 정가 : 12800, 할인가 : 11520
# 버네스 트레이닝팬츠
# 정가 : 16800, 할인가 : None
# 펩트휘트니스팬츠
# 정가 : 16800, 할인가 : None
# 랩슨휘트니스팬츠
# 정가 : 12900, 할인가 : None
# 더프세미배기팬츠
# 정가 : 28900, 할인가 : 20230
# 제르티밴딩팬츠
# 정가 : 34900, 할인가 : 20940
# 리케일큐롯팬츠
# 정가 : 24800, 할인가 : 9920
# 케이슨와이드팬츠
# 정가 : 15900, 할인가 : 7950
# 티블런수술팬츠~G
# 정가 : 34900, 할인가 : 20940
# 테로우일자팬츠~F
# 정가 : 32900, 할인가 : 19740
# 피렌체와이드팬츠
# 정가 : 19800, 할인가 : 7920
# 제이리와이드팬츠
# 정가 : 17900, 할인가 : None
# 카밀라데님팬츠~GN
# 정가 : 32900, 할인가 : 19740
# 페이디와이드팬츠~REX
# 정가 : 36900, 할인가 : 22140
# 쏘네밴딩숏팬츠
# 정가 : 10900, 할인가 : None
# 리포코팅스키니팬츠~TY
# 정가 : 32900, 할인가 : 19740
# 페비스밴딩일자팬츠~RJ
# 정가 : 23900, 할인가 : 14340
# 나르시와이드팬츠
# 정가 : 32900, 할인가 : 23030
# 다에크데미지팬츠~NE
# 정가 : 34900, 할인가 : 20940
# 리노브밴딩일자팬츠~F
# 정가 : 32900, 할인가 : 19740
# 리스벳일자팬츠~BM
# 정가 : 19900, 할인가 : 11940
# 올리피슬랙스팬츠
# 정가 : 27900, 할인가 : 16740
# 앨비부츠컷밴딩팬츠~F
# 정가 : 39000, 할인가 : 19500
# 코트나일자팬츠~MF
# 정가 : 32900, 할인가 : 19740
# 위튼롤업팬츠~F
# 정가 : 29900, 할인가 : 17940
# 마델리면통팬츠~F
# 정가 : 24900, 할인가 : 14940
# 뮬린부츠컷슬랙스팬츠
# 정가 : 34900, 할인가 : 20940
# 켄젤데님일자팬츠~LC
# 정가 : 36900, 할인가 : 22140
# 유나잇데님숏팬츠~REX
# 정가 : 29900, 할인가 : 17940
# 험벨기모스키니팬츠~MD
# 정가 : 19900, 할인가 : 7960
# 칙크본딩기모스키니팬츠~LT
# 정가 : 29900, 할인가 : 17940
# 에트란 카코팬츠~SJ
# 정가 : 39800, 할인가 : 23880
# 로아망 와이드팬츠~QT
# 정가 : 29900, 할인가 : 17940
# 큐럼벨트 숏팬츠~MC
# 정가 : 27900, 할인가 : 16740
# 제니트5부팬츠~F
# 정가 : 23900, 할인가 : 14340
# http://itproject.ezenac.co.kr/springmyshop/product/best?page=3&keyword=%ED%8C%AC%EC%B8%A0
# 브론드 기모밴딩슬랙스팬츠
# 정가 : 27800, 할인가 : None
# 뷰덴 슬랙스팬츠
# 정가 : 19800, 할인가 : None
# 로야트기모 일자팬츠~LC
# 정가 : 32800, 할인가 : 19680
# 크렉스 일자팬츠~NS
# 정가 : 25800, 할인가 : 15480
# 듀잇 밴딩스키니팬츠~JK
# 정가 : 27800, 할인가 : 16680
# 데이원코듀로이 일자팬츠~BI
# 정가 : 29800, 할인가 : 17880
# 리크룬 융스키니팬츠~NE
# 정가 : 34800, 할인가 : 20880
# 켄포티 와이드팬츠
# 정가 : 19800, 할인가 : None
# 에인브부츠컷팬츠
# 정가 : 24900, 할인가 : None
# 티볼기모 이중와이드팬츠
# 정가 : 19800, 할인가 : 11880
# 로렐 일자핏팬츠~LC
# 정가 : 29800, 할인가 : 17880
# 라이톤 일자팬츠
# 정가 : 27900, 할인가 : 16740
# 크레핏기모 밴딩팬츠~MS
# 정가 : 29800, 할인가 : 17880
# 별빛 데님일자팬츠~SB
# 정가 : 34800, 할인가 : None
# 레이볼밴딩 일자팬츠~MI
# 정가 : 29800, 할인가 : None
# 퀴티스 일자팬츠~TB
# 정가 : 28900, 할인가 : None
# 모디브기모 스키니팬츠~TB
# 정가 : 29800, 할인가 : None
# 셰인밴딩팬츠
# 정가 : 32900, 할인가 : 6580
# 씨엔더 일자팬츠~TB
# 정가 : 34800, 할인가 : None
# 마티밴딩 와이드팬츠
# 정가 : 9900, 할인가 : 5940
# 스트랩 밴딩와이드팬츠~TY
# 정가 : 32800, 할인가 : None
# 페이티 숏팬츠~CC
# 정가 : 26000, 할인가 : None
# 세레트 숏팬츠~SE
# 정가 : 29000, 할인가 : 11600
# 웨이드 숏팬츠~RJ
# 정가 : 22800, 할인가 : None
# 프레즐 일자팬츠~BM
# 정가 : 31000, 할인가 : None
# 프론드 일자팬츠~QT
# 정가 : 32000, 할인가 : None
# 더블비 일자팬츠~BEE
# 정가 : 32900, 할인가 : None
# 위트윈 밴딩와이드팬츠
# 정가 : 24800, 할인가 : None
# 럽셀프 숏팬츠~DE
# 정가 : 28000, 할인가 : None
# 오가닉 배기팬츠
# 정가 : 25900, 할인가 : None
# 페리마 밴딩숏팬츠~K
# 정가 : 22000, 할인가 : None
# 루벳카모숏팬츠
# 정가 : 35900, 할인가 : 21540
# 리디브 숏팬츠~W
# 정가 : 27900, 할인가 : None
# 아울리줄무늬 밴딩팬츠
# 정가 : 9900, 할인가 : 5940
# 죠니프 밴딩숏팬츠
# 정가 : 24000, 할인가 : 12000
# 줄리 와이드팬츠
# 정가 : 10000, 할인가 : 9000
# http://itproject.ezenac.co.kr/springmyshop/product/best?page=4&keyword=%ED%8C%AC%EC%B8%A0
# 쇼니크 와이드팬츠~TY
# 정가 : 34900, 할인가 : None
# 비비드 린넨밴딩팬츠
# 정가 : 29900, 할인가 : 14950
# 헤르민 린넨와이드팬츠
# 정가 : 22000, 할인가 : None
# 위키 린넨밴딩숏팬츠
# 정가 : 17900, 할인가 : None
# 네리트 7부팬츠~CO
# 정가 : 59800, 할인가 : 41860
# 지트링린넨 와이드팬츠
# 정가 : 49800, 할인가 : 29880
# 스이커 숏팬츠~NS
# 정가 : 24800, 할인가 : None
# 하이투 구제부츠컷팬츠~K
# 정가 : 32900, 할인가 : None
# 로렐라인 밴딩팬츠
# 정가 : 43900, 할인가 : None
# 타리미 데님팬츠~D
# 정가 : 32900, 할인가 : None
# 썬플라워 와이드팬츠
# 정가 : 25000, 할인가 : 12500
# 크랭 부츠컷팬츠~NS
# 정가 : 29900, 할인가 : None
# 레어드 부츠컷데님팬츠~BC
# 정가 : 32900, 할인가 : None
# 스캇치 일자데님팬츠~REX
# 정가 : 37900, 할인가 : None
# 크리켄 멜빵팬츠~LC
# 정가 : 49800, 할인가 : None
# 샤샤 데님일자팬츠~REX
# 정가 : 36800, 할인가 : None
# 레트롱 밴딩스키니팬츠~WE
# 정가 : 37900, 할인가 : None
# 센크밴딩 일자팬츠~JS
# 정가 : 32900, 할인가 : None
# 포센 부츠컷팬츠~BK
# 정가 : 34900, 할인가 : None
# 크러시 일자면팬츠~MU
# 정가 : 21900, 할인가 : None
# 슬리딧린넨 와이드팬츠
# 정가 : 59800, 할인가 : 53820
# 홋타기모 밴딩팬츠~CO
# 정가 : 59800, 할인가 : None
# 보튼 기모 카고팬츠~CO
# 정가 : 38000, 할인가 : 26600
# 밀르카모팬츠~CO
# 정가 : 59800, 할인가 : None
# 원쓰 루즈팬츠~CB
# 정가 : 36900, 할인가 : None
# 네프티 밴딩기모팬츠~D
# 정가 : 34000, 할인가 : None
# 프리멜 데님팬츠~JS
# 정가 : 34000, 할인가 : None
# 이너트 밍크부츠컷팬츠~W
# 정가 : 29900, 할인가 : None
# 세이트 와이드데님팬츠~TY
# 정가 : 34900, 할인가 : None
# 슬로우 부츠컷데님팬츠~W
# 정가 : 36900, 할인가 : None
# 레이크 일자데님팬츠
# 정가 : 24900, 할인가 : None
# 데라트 뒷밴딩 배기팬츠~TY
# 정가 : 29900, 할인가 : None
# 크렐라 일자데님팬츠~DJ
# 정가 : 29800, 할인가 : None
# 테룬 일자팬츠~NS
# 정가 : 25900, 할인가 : None
# 레이브 카고밴딩팬츠
# 정가 : 32900, 할인가 : None
# 론네 부츠컷데님팬츠~WE
# 정가 : 36900, 할인가 : None
# http://itproject.ezenac.co.kr/springmyshop/product/best?page=5&keyword=%ED%8C%AC%EC%B8%A0
# 프롬 새미부츠컷팬츠~F
# 정가 : 32900, 할인가 : None
# 제이론 데님부츠컷팬츠~TY
# 정가 : 34900, 할인가 : None
# 드림 부츠컷데님팬츠~WE
# 정가 : 37900, 할인가 : None
# 텔로 일자데님팬츠~WE
# 정가 : 37900, 할인가 : None
# 톡스 데님일자팬츠~WE
# 정가 : 32900, 할인가 : None
# 넬로즈 일자데님팬츠~NS
# 정가 : 32900, 할인가 : None
# 메르온 기모포켓팬츠~DC
# 정가 : 35000, 할인가 : None
# 구모 밴딩배기팬츠
# 정가 : 19800, 할인가 : None
# 위즐 밴딩팬츠~WE
# 정가 : 37900, 할인가 : None
# 럼드 일자기모팬츠~DC
# 정가 : 33000, 할인가 : None
# [인싸코듀로이2탄] 엠마 기모코듀로이팬츠
# 정가 : 34000, 할인가 : 27200
# 페비 밴딩팬츠~BG
# 정가 : 32900, 할인가 : None
# 쿼티링 일자팬츠~TB
# 정가 : 31800, 할인가 : None
# 로드온 일자팬츠~HE
# 정가 : 37800, 할인가 : None
# 오들리 일자기모팬츠~JS
# 정가 : 27900, 할인가 : None
# 레이빗 일자데님기모팬츠~NS
# 정가 : 32000, 할인가 : None
# 벨루아 일자데님팬츠~NS
# 정가 : 34000, 할인가 : None
# 플레이 조거팬츠
# 정가 : 21800, 할인가 : None
# 트린트 건빵팬츠
# 정가 : 23800, 할인가 : None
# 로이튼 데님팬츠~RJ
# 정가 : 27000, 할인가 : None
# [인싸부츠컷팬츠1탄] 에이든 밍크부츠컷팬츠
# 정가 : 22000, 할인가 : 19800
# 레바 밴딩부츠컷팬츠
# 정가 : 19800, 할인가 : None
# 솔제드 뒷밴딩 일자팬츠~MO
# 정가 : 29800, 할인가 : None
# 어위크 기모데님일자팬츠~BK
# 정가 : 35900, 할인가 : None
# 시티즈 일자팬츠~F
# 정가 : 29800, 할인가 : None
# 미스티 배기팬츠~DO
# 정가 : 35000, 할인가 : None
# 일런드 일자데님팬츠~NS
# 정가 : 32900, 할인가 : None
# 스티니 기모밴딩일자팬츠~NS
# 정가 : 26900, 할인가 : None
# 크라트 세미부츠컷 기모밴딩팬츠~SJ
# 정가 : 24000, 할인가 : None
# 루트란 배기팬츠~JS
# 정가 : 32900, 할인가 : None
# [인싸밴딩팬츠1탄]띠타뉴 기모밴딩팬츠
# 정가 : 24800, 할인가 : 19840
# 필렉스 밴딩팬츠
# 정가 : 16800, 할인가 : None
# 핀드펀 부츠컷데님팬츠~SN
# 정가 : 34800, 할인가 : None
# 켈리 슬랙스팬츠
# 정가 : 47000, 할인가 : None
# 빈야드 지퍼밴딩팬츠
# 정가 : 27000, 할인가 : None
# 코펠 슬랙스팬츠
# 정가 : 19800, 할인가 : None
# http://itproject.ezenac.co.kr/springmyshop/product/best?page=6&keyword=%ED%8C%AC%EC%B8%A0
# 시그트 뒷밴딩배기팬츠~SN
# 정가 : 35000, 할인가 : None
# 바웃딘 일자데님팬츠~SN
# 정가 : 35000, 할인가 : None
# 민트라인 죠거팬츠
# 정가 : 18000, 할인가 : None
# [인싸코듀로이1탄]코르튜 골덴팬츠
# 정가 : 26800, 할인가 : 21440
# 모브 배기데님팬츠~K
# 정가 : 32900, 할인가 : None
# 젠슬러 뒷밴딩팬츠~NE
# 정가 : 35000, 할인가 : None
# 슬리카 밴딩팬츠
# 정가 : 16900, 할인가 : None
# 베이샤 밴딩팬츠
# 정가 : 33000, 할인가 : None
# 브라보 슬림배기팬츠
# 정가 : 34000, 할인가 : None
# 써포트 데님팬츠~SP
# 정가 : 32000, 할인가 : None
# 도레크 데님부츠컷팬츠~TB
# 정가 : 33000, 할인가 : None
# 제링티 쭈리밴딩팬츠
# 정가 : 22800, 할인가 : 20520
# 텐슈 새미배기팬츠~BC
# 정가 : 33000, 할인가 : None
# 드림 일자팬츠~D
# 정가 : 43000, 할인가 : None
# 크린티 데님팬츠~GN
# 정가 : 29800, 할인가 : None
# 페란 데님팬츠~CC
# 정가 : 34000, 할인가 : None
# 로바 뒷밴딩일자팬츠~TY
# 정가 : 36800, 할인가 : None
# 밀리터리 카고팬츠~CO
# 정가 : 55000, 할인가 : None
# 크롱드 부츠컷데님팬츠~TY
# 정가 : 35000, 할인가 : None
# 마리오 일자팬츠~MO
# 정가 : 24800, 할인가 : None
# 델라엔 멜빵팬츠
# 정가 : 33000, 할인가 : None
# 메코티 배기팬츠
# 정가 : 29800, 할인가 : None
# 비튼 데미지데님팬츠~SN
# 정가 : 35000, 할인가 : None
# 소울 데님일자팬츠~RJ
# 정가 : 27900, 할인가 : None
# 배티아 데님팬츠
# 정가 : 39800, 할인가 : None
# 투러브 일자데님팬츠~RJ
# 정가 : 27800, 할인가 : None
# 로델 네온죠거팬츠
# 정가 : 27800, 할인가 : 25020
# 틴트 일자팬츠~NS
# 정가 : 27800, 할인가 : None
# 스무스 일자핏팬츠
# 정가 : 24800, 할인가 : None
# 블루밍 데님 와이드팬츠
# 정가 : 35000, 할인가 : None
# 마멜 일자 데님팬츠~BM
# 정가 : 33000, 할인가 : None
# 블루틴 사선숏팬츠~BG
# 정가 : 29800, 할인가 : None
# 니탑스 4부팬츠~MT
# 정가 : 27000, 할인가 : None
# 퍼텐 밴딩숏팬츠
# 정가 : 22000, 할인가 : 19800
# 노이튼 데님팬츠~RJ
# 정가 : 28900, 할인가 : None
# 루시안 5부팬츠~BG
# 정가 : 33000, 할인가 : None
# http://itproject.ezenac.co.kr/springmyshop/product/best?page=7&keyword=%ED%8C%AC%EC%B8%A0
# 디오케이 데님팬츠~K
# 정가 : 35000, 할인가 : None
# 플리트와이드팬츠
# 정가 : 39800, 할인가 : None
# [인싸죠거2탄]클로베 기모카고죠거팬츠
# 정가 : 23800, 할인가 : 19040
# [인싸죠거7탄] 메이빈 카고죠거팬츠
# 정가 : 23800, 할인가 : 21420
# [인싸부츠컷3탄] 페이듀 부츠컷팬츠
# 정가 : 15800, 할인가 : 14220
# 블로디주름와이드팬츠
# 정가 : 49900, 할인가 : 9980
# 모니카 슬랙스팬츠
# 정가 : 39900, 할인가 : 23940
# [인싸밴딩2탄] 더뮤 밴딩팬츠
# 정가 : 34000, 할인가 : 27200
# 오키디 일자데님팬츠~TY
# 정가 : 36000, 할인가 : None
# 다우트 데님팬츠~D
# 정가 : 44000, 할인가 : None
# 마피아 트임팬츠
# 정가 : 16900, 할인가 : None
# 엘슨 연청 세미배기팬츠
# 정가 : 39800, 할인가 : None
# 렌샤 밴딩팬츠
# 정가 : 9900, 할인가 : None
# 우나트 골지후드팬츠 세트
# 정가 : 35000, 할인가 : None
# 디르코 밴딩팬츠
# 정가 : 27000, 할인가 : None
# 에이틀 데님팬츠
# 정가 : 19800, 할인가 : None
# 테이닝 4부데님팬츠
# 정가 : 37800, 할인가 : None
# [인싸팬츠10탄]로데즈 와이드팬츠
# 정가 : 49800, 할인가 : 44820
# 스트랩 골지밴딩팬츠
# 정가 : 16800, 할인가 : None
# 케이브 밴딩팬츠
# 정가 : 10000, 할인가 : None
# 레츠고 체크배기팬츠
# 정가 : 22000, 할인가 : None
# 핏스트 5부데님팬츠
# 정가 : 27000, 할인가 : None
# [인싸죠거10탄] 리츠죠거팬츠
# 정가 : 16900, 할인가 : 15210
# 리스트 일자데님팬츠
# 정가 : 22000, 할인가 : None
# 헬로디밴딩팬츠
# 정가 : 9900, 할인가 : 8910
# 코븐 4부데님팬츠
# 정가 : 16800, 할인가 : None
# [인싸팬츠12탄]레트로 플라워 패턴팬츠
# 정가 : 36800, 할인가 : 33120
# 러뷰드 린넨와이드팬츠
# 정가 : 49800, 할인가 : 44820
# 마렌 밴딩팬츠
# 정가 : 26800, 할인가 : 24120

# %% [markdown]
# # #04. 수집 결과를 데이터 프레임으로 변환

# %%
df = DataFrame(data_list)
df
# Out:
#                        상품명     정가      할인가  \
# 0                블린체휘트니스팬츠  25900      NaN
# 1                플러튼휘트니스팬츠  25900      NaN
# 2              메이건7부트레이닝팬츠  15900      NaN
# 3              루더스휘트니스치마팬츠  19900      NaN
# 4                론사선트레이닝팬츠  21900  13140.0
# ..                     ...    ...      ...
# 240                헬로디밴딩팬츠   9900   8910.0
# 241              코븐 4부데님팬츠  16800      NaN
# 242  [인싸팬츠12탄]레트로 플라워 패턴팬츠  36800  33120.0
# 243            러뷰드 린넨와이드팬츠  49800  44820.0
# 244                마렌 밴딩팬츠  26800  24120.0
#
#                                                     설명
# 0    ★휘트니스룩★텐션좋은 쫀쫀한 스판기에 기능성원단으로 부담없이 입기 좋은 휘트니스 팬...
# 1    다리 라인을 매끄럽게 정리해주는 쫀쫀한 신축성에 아랫배까지 잡아주는 긴 밑위기장으로...
# 2    ★휘트니스룩★ 곡선 옆라인이 바디라인을 더욱 날씬하게! 쫀쫀한 허리밴딩이 아랫배를 ...
# 3    스커트가 레이어드된 피트니스팬츠입니다. 배색라인 포인트와 쫀쫀한 텐션으로 다리라인을...
# 4    ★휘트니스룩★옆라인 사선 배색 포인트로 더욱 얇아보이는 다리라인으로 만들어준답니당 ...
# ..                                                 ...
# 240  신축성 좋은 허리밴딩으로 편안하게~ 9가지 다양한 컬러로 넓은 초이스~ one si...
# 241            은은한 워싱디자인과 밑단 컷팅스타일로 빈티지하게! size(S~XXL)
# 242     찰랑찰랑 시원한 느낌의 패턴 소재로 편안한 밴딩 팬츠 아이템! FREE(44~66)
# 243  ★자체제작 + 루즈핏★ 허리는밴딩으로 편안하게~ 입어주면 우아한 룩으로 완성시켜주는...
# 244      쫀득한 스판원단으로 다리라인에 편안하게 입기 좋은 밴딩팬츠! FREE,L size
#
# [245 rows x 4 columns]

# %% [markdown]
# # #05. 데이터프레임을 엑셀로 저장

# %%
df.to_excel('상품정보(%s).xlsx' % keyword, index=False)
